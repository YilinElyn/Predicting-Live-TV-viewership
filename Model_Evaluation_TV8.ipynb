# %% [markdown]
# ## Model_TV8
# ## Table of Contents:
# * [0. Importing dependencies](#dependencies)
# * [1. Setting up of the dataset](#1.0)
#     * [1.1 Importing of the dataset](#1.1)
#     * [1.2 Preparing the dataset](#1.2)
# * [2. Model applicability testing](#2.0)

# %% [markdown]
# # 0. Importing dependencies  <a class="anchor" id="dependencies"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xgboost as xgb
import lightgbm as lgb
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from math import sqrt
import joblib

# %% [markdown]
# # 1. Setting up of the dataset <a class="anchor" id="1.0"></a>

# %% [markdown]
# ## 1.1 Importing of the dataset <a class="anchor" id="1.1"></a>

# %%
# Load the final dataframe
file_path = 'C:/Users/support/Desktop/Yılın Yang/df_final_TV8.csv'
df_final = pd.read_csv(file_path)

print(df_final.columns)
# Out:
# Index(['trend_vc', 'weekly_vc', 'trend_i', 'weekly_i', 'trend_ud', 'weekly_ud',
#        'videoConsumption', 'impression'],
#       dtype='object')

# %% [markdown]
# ## 1.2 Preparing the dataset <a class="anchor" id="1.2"></a>

# %%
# Define input features and target outputs
prophet_features = ['weekly_vc', 'weekly_i', 'weekly_ud']
targets = ['videoConsumption', 'impression']

all_features = prophet_features + targets  # Include both Prophet features and original data
# Create test_data

test_data = df_final[all_features].values

# %% [markdown]
# # 2. Model applicability testing <a class="anchor" id="2.0"></a>

# %%
# Load the best models
best_rf_model = joblib.load('C:/Users/support/Desktop/Yılın Yang/Best_RF_Model.pkl')
best_lgbm_model = joblib.load('C:/Users/support/Desktop/Yılın Yang/Best_LightGBM_Model.pkl')
best_xgb_model = joblib.load('C:/Users/support/Desktop/Yılın Yang/Best_XGBoost_Model.pkl')

# %%
# Function for rolling window forecast
def rolling_window_forecast(data, window_size, forecast_horizon, model):
    predictions_vc, predictions_i = [], []
    true_values_vc, true_values_i = [], []

    for start in range(0, len(data) - window_size - forecast_horizon, forecast_horizon):
        end = start + window_size
        X_train = data[start:end]
        y_train_vc = data[start:end, -2]
        y_train_i = data[start:end, -1]

        X_test = data[end:end + forecast_horizon]
        y_test_vc = data[end:end + forecast_horizon, -2]
        y_test_i = data[end:end + forecast_horizon, -1]

        y_train = np.vstack((y_train_vc, y_train_i)).T
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)

        predictions_vc.extend(y_pred[:, 0])
        predictions_i.extend(y_pred[:, 1])
        true_values_vc.extend(y_test_vc)
        true_values_i.extend(y_test_i)

    return predictions_vc, predictions_i, true_values_vc, true_values_i

# %%
# Final evaluation using rolling window on test set
forecast_horizon = 1440  # fixed forecast horizon
window_size = 1440 * 7  # best window size

# %%
# Function to calculate Percentage RMSE
def calculate_percentage_rmse(rmse, true_values):
    mean_actual = np.mean(true_values)
    return (rmse / mean_actual) * 100

# %%
def evaluate_model_rolling_window(model, data, window_size, forecast_horizon):
    predictions_vc, predictions_i, true_values_vc, true_values_i = rolling_window_forecast(data, window_size, forecast_horizon, model)
    mse_vc = mean_squared_error(true_values_vc, predictions_vc)
    rmse_vc = sqrt(mse_vc)
    mse_i = mean_squared_error(true_values_i, predictions_i)
    rmse_i = sqrt(mse_i)
    pr_rmse_vc = calculate_percentage_rmse(rmse_vc, true_values_vc)
    pr_rmse_i = calculate_percentage_rmse(rmse_i, true_values_i)
    return {
        "predictions_vc": predictions_vc, "predictions_i": predictions_i,
        "true_values_vc": true_values_vc, "true_values_i": true_values_i,
        "mse_vc": mse_vc, "rmse_vc": rmse_vc,
        "mse_i": mse_i, "rmse_i": rmse_i,
        "pr_rmse_vc": pr_rmse_vc, "pr_rmse_i": pr_rmse_i
    }

# %%
# Plotting Predictions as Time Series and Scatter Plot
def plot_time_series(true_values, predictions, title):
    plt.figure(figsize=(10, 6))
    plt.plot(true_values, label='Actual')
    plt.plot(predictions, label='Predicted', linestyle='--')
    plt.title(title)
    plt.xlabel('Time Index')
    plt.ylabel('Value')
    plt.legend()
    plt.tight_layout()
    plt.show()

def plot_predictions(true_values, predictions, title):
    true_values = np.array(true_values)  
    predictions = np.array(predictions) 
    plt.figure(figsize=(8, 6))
    plt.scatter(true_values, predictions, alpha=0.3)
    plt.plot([true_values.min(), true_values.max()], [true_values.min(), true_values.max()], 'k--', lw=3)
    plt.xlabel('Actual')
    plt.ylabel('Predicted')
    plt.title(title)
    plt.tight_layout()
    plt.show()

# %%
def process_model(model, test_data, window_size, forecast_horizon, model_name, all_features):
    results = evaluate_model_rolling_window(model, test_data, window_size, forecast_horizon)
    plot_time_series(results["true_values_vc"], results["predictions_vc"], f'{model_name} - Video Consumption Time Series')
    plot_predictions(results["true_values_vc"], results["predictions_vc"], f'{model_name} - Video Consumption Scatter Plot')
    plot_time_series(results["true_values_i"], results["predictions_i"], f'{model_name} - Impression Time Series')
    plot_predictions(results["true_values_i"], results["predictions_i"], f'{model_name} - Impression Scatter Plot')
    
    print(f"{model_name} - Video Consumption MSE: {results['mse_vc']:.3f}, RMSE: {results['rmse_vc']:.3f}, PRMSE: {results['pr_rmse_vc']:.3f}%")
    print(f"{model_name} - Impression MSE: {results['mse_i']:.3f}, RMSE: {results['rmse_i']:.3f}, PRMSE: {results['pr_rmse_i']:.3f}%")
    
    if hasattr(model, 'feature_importances_'):
        feature_importances = model.feature_importances_
        plot_feature_importance(model, all_features)
        print("Feature Importances:", list(zip(all_features, feature_importances)))
    elif hasattr(model.estimators_[0], 'feature_importances_'):  # For MultiOutputRegressor
        feature_importances = model.estimators_[0].feature_importances_
        plot_feature_importance(model.estimators_[0], all_features)
        print("Feature Importances:", list(zip(all_features, feature_importances)))

def plot_feature_importance(model, feature_names):
    plt.figure(figsize=(10, 6))
    importances = model.feature_importances_
    indices = np.argsort(importances)
    plt.title('Feature Importances')
    plt.barh(range(len(indices)), importances[indices], color='b', align='center')
    plt.yticks(range(len(indices)), [feature_names[i] for i in indices])
    plt.xlabel('Relative Importance')
    plt.show()

process_model(best_rf_model, test_data, window_size, forecast_horizon, "Random Forest", all_features)
process_model(best_lgbm_model, test_data, window_size, forecast_horizon, "LightGBM", all_features)
process_model(best_xgb_model, test_data, window_size, forecast_horizon, "XGBoost", all_features)
# Out:
# Random Forest - Video Consumption MSE: 115883357.954, RMSE: 10764.913, PRMSE: 16.479%
# Random Forest - Impression MSE: 13065.887, RMSE: 114.306, PRMSE: 5.772%
# Feature Importances: [('weekly_vc', 2.0541901975478415e-06), ('weekly_i', 4.5237578049066205e-06), ('weekly_ud', 2.196673037957055e-06), ('videoConsumption', 0.9999844371779015), ('impression', 6.788201058008323e-06)]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 40758.700694
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1388.208433
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000276 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 42689.925496
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001244 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1533.698909
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47788.437103
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1718.265575
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 53217.641270
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000258 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1912.873512
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000645 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 52088.493651
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000692 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1900.521925
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51027.037202
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1868.937401
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000780 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 55272.983433
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1924.015079
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 54389.719147
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000817 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1907.880655
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 53180.651587
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1892.628472
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000245 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51748.564881
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1883.080456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51083.973512
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000243 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1889.134028
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51209.349702
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000236 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1892.400397
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51170.127480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1901.346329
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000630 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 50925.277282
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000640 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1896.402877
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000633 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 52533.717361
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1922.902679
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000240 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 52069.448810
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1898.584821
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 52520.256746
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1923.668750
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000678 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 51849.461706
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1935.884127
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000625 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47947.362897
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1924.161012
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 42876.045933
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1859.725992
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000711 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 37383.622917
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1767.793452
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 33791.480556
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000334 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1676.241071
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000639 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 32699.222619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001037 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1610.505853
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000651 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 28523.688294
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1464.929861
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000674 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 23981.485615
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000656 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1320.093254
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000237 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 21488.317063
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000655 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1191.458829
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001081 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 19828.881548
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1115.996726
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000714 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 21602.285714
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000663 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1078.698413
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 25332.184226
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000643 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1165.395139
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125981 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 26392.918155
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000231 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1192.089385
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000623 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 26898.731052
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000488 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1231.528472
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 27705.814683
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1266.516667
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000403 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 30800.469444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000743 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1351.904167
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000642 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 37017.885317
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000722 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1451.343353
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000611 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 39426.940972
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1532.776885
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 41924.326587
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000252 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1536.132937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000507 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 40850.639980
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1519.461409
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000441 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 43547.762996
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000427 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1538.219544
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000680 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47478.727381
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1585.130456
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000766 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 48464.131647
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000714 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1564.852183
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 46375.490873
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1537.722817
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001167 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 44083.050298
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000297 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1529.222619
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 41550.678571
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000832 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1487.832837
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000637 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 41854.879861
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000651 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1488.210516
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000671 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 41755.632242
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000664 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1501.126290
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 40073.094048
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000251 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1476.091468
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 39265.651190
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1470.509821
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000636 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 38698.247123
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1472.825992
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000798 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 39742.684722
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001054 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1472.372222
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000295 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 39880.601587
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000632 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1498.997520
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000659 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 41227.076687
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000657 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1553.097321
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000246 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 42027.902976
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001138 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1581.984921
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000686 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 42804.161111
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1620.332143
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000730 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 44760.113889
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1670.233929
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 45667.788988
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002058 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1690.910615
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 46167.121627
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000254 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1700.106845
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47140.424206
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000838 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1718.979861
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000270 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47429.903869
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000731 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1724.554067
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000259 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47302.711706
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000714 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1740.824306
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000672 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47063.548016
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001502 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1737.119444
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001004 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 46850.808333
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000768 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1723.076984
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000618 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47009.570437
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000681 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1718.998115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000956 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 47369.032937
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.125149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1734.033234
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000677 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 46483.068849
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001477 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1728.678869
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 46876.942758
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 1741.604067
# ...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2574.533036
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000232 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 95737.795238
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000643 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2578.213393
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000265 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 94413.551389
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001031 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2597.143254
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000645 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 94077.057837
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2584.652480
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000255 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 92641.774107
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125463 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2562.785020
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000624 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 92306.808333
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000240 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2554.885119
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 92251.670437
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000715 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2556.293948
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000607 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 92226.106151
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000704 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2571.518452
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000646 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 92557.140179
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000614 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2585.608433
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000666 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 93208.023214
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000633 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2567.473115
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000626 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 93678.421825
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2612.148710
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000667 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 95229.232540
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000626 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2672.672222
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000256 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 95611.593353
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000664 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2703.388294
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001337 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 98850.417361
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2760.542361
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000619 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 98971.579464
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000771 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2770.976984
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 97823.513690
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000621 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2779.502976
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000250 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 96917.391667
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.125837 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2764.668056
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.125465 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 96459.541567
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000629 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2749.403274
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001022 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 95253.644643
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000660 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2719.717758
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000627 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 95514.285516
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000340 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2722.406944
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000746 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 93666.419841
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000669 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2703.336310
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000628 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 93316.328770
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000654 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1275
# [LightGBM] [Info] Number of data points in the train set: 10080, number of used features: 5
# [LightGBM] [Info] Start training from score 2679.639087
# LightGBM - Video Consumption MSE: 130602150.136, RMSE: 11428.130, PRMSE: 17.495%
# LightGBM - Impression MSE: 77371.832, RMSE: 278.158, PRMSE: 14.046%
# Feature Importances: [('weekly_vc', 521), ('weekly_i', 254), ('weekly_ud', 241), ('videoConsumption', 4613), ('impression', 471)]
# XGBoost - Video Consumption MSE: 125085869.445, RMSE: 11184.179, PRMSE: 17.121%
# XGBoost - Impression MSE: 158573.656, RMSE: 398.213, PRMSE: 20.109%
# Feature Importances: [('weekly_vc', 6.886767e-05), ('weekly_i', 8.538455e-05), ('weekly_ud', 2.5185604e-05), ('videoConsumption', 0.99975276), ('impression', 6.78261e-05)]
